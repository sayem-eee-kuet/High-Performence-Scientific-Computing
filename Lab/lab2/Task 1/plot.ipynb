# %%
import numpy as np
import matplotlib.pyplot as plt

f = open('CPUData1.dat', 'r')
lines = f2.readlines()
f2.close()

x1 = []
y1 = []

for line in lines:
    p = line.split()
    x1.append(float(p[0]))
    y1.append(float(p[1]))
   
xv = np.array(x1)
yv = np.array(y1)

plt.plot(xv, yv)

plt.show()
